# %%
from PIL import Image
from matplotlib import pyplot as plt
from collections import Counter
from scipy import ndimage as ndi
from skimage import feature
import scipy.misc
import scipy
import numpy as np
import statistics
import random
import time

# %%
def open_img(img):
    route = (r"nami.jpg" + img)
    img = Image.open(route)
    img.show()

open_img("image16bits.jpg")

# %%
import matplotlib.pyplot as plt
import cv2
import numpy as np

#Funcionalidad de jupiter para que abra la imagen en un markdonw
# %matplotlib inline
plt.rcParams['figure.figsize'] = [10,5]

# %%
img = cv2.imread('nami.jpg')
print('size: ', img.shape)
# Out:
# size:  (1200, 1200, 3)

# %%
plt.imshow(img)
plt.show()

# %%
imga = cv2.imread('nami.jpg', cv2.IMREAD_COLOR)

plt.figure(figsize=(12, 4))

plt.subplot(141)
plt.title('Original')
plt.imshow(cv2.cvtColor(imga, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(142)
plt.title('Canal R')
plt.imshow(imga[:, :, 0], cmap='gray')
plt.axis('off')

plt.subplot(143)
plt.title('Canal G')
plt.imshow(imga[:, :, 1], cmap='gray')
plt.axis('off')

plt.subplot(144)
plt.title('Canal B')
plt.imshow(imga[:, :, 2], cmap='gray')
plt.axis('off')

plt.show()

# %%
imga = cv2.imread('nami.jpg', cv2.IMREAD_COLOR)

plt.figure(figsize=(12, 4))

plt.subplot(141)
plt.title('Original')
plt.imshow(cv2.cvtColor(imga, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(142)
plt.title('Canal R')
plt.imshow(imga[:, :, 0], cmap='Reds')
plt.axis('off')

plt.subplot(143)
plt.title('Canal G')
plt.imshow(imga[:, :, 1], cmap='Blues')
plt.axis('off')

plt.subplot(144)
plt.title('Canal B')
plt.imshow(imga[:, :, 2], cmap='Greens')
plt.axis('off')

plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image =  cv2.imread('nami.jpg', cv2.IMREAD_GRAYSCALE)

original_img = image.dtype 
print('Profundida original:', original_img)

image_16bits = np.uint16(image)

nueva_img = image_16bits.dtype
print('Profundida original:', nueva_img)

cv2.imwrite('image16bits.jpg', image_16bits)

img_guardada = cv2.imread('image16bits.jpg', cv2.IMREAD_UNCHANGED)

plt.figure(figsize=(12, 4))

plt.subplot(121)
plt.title('Original')
plt.imshow(image, cmap = 'gray')
plt.axis('off')

plt.subplot(122)
plt.title('Imagen tratada 16 Bits')
plt.imshow(img_guardada, cmap = 'gray')
plt.axis('off')
# Out:
# Profundida original: uint8
# Profundida original: uint16
# (-0.5, 1199.5, 1199.5, -0.5)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams['figure.figsize'] = [5,2.5]

imgInicialRgb = cv2.imread('nami.jpg')
print(imgInicialRgb.shape)
plt.imshow(cv2.cvtColor(imgInicialRgb, cv2.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

imagenRGB = plt.imread('nami.jpg')
print(imagenRGB)
plt.imshow(imagenRGB)
plt.axis('off')
plt.show
# Out:
# (1200, 1200, 3)
# [[[168 148 123]
#   [179 142 126]
#   [195 133 134]
#   ...
#   [  0  17  76]
#   [  0  15  56]
#   [  0  17  46]]
#
#  [[169 147 123]
#   [179 141 128]
#   [194 134 134]
#   ...
#   [  0  13  70]
#   [  0  13  53]
#   [  0  16  46]]
#
#  [[172 145 124]
#   [180 140 128]
#   [193 135 134]
#   ...
#   [  0  11  57]
#   [  0  11  49]
#   [  6  14  50]]
#
#  ...
#
#  [[210 196 196]
#   [210 196 196]
#   [209 195 195]
#   ...
#   [217 148 176]
#   [217 148 176]
#   [217 148 176]]
#
#  [[210 196 196]
#   [210 196 196]
#   [209 195 195]
#   ...
#   [217 148 176]
#   [217 148 176]
#   [217 148 176]]
#
#  [[210 196 196]
#   [210 196 196]
#   [209 195 195]
#   ...
#   [217 148 176]
#   [217 148 176]
#   [217 148 176]]]
# <function matplotlib.pyplot.show(close=None, block=None)>
