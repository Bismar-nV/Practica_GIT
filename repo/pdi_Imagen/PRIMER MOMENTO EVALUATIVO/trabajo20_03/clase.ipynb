# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

def solarizar(image, umbral):
    img_solarizar = np.where(image < umbral, image, 255 - image)
    return img_solarizar 

def posterizar(image, nivel):
    f_nvl = 255 / nivel
    img_poster = np.round(image / f_nvl) * f_nvl
    return img_poster.astype(np.uint8)

imagen = cv2.imread('nami.jpg')
img_gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)

##########################################

umbral = 127
img_sol = solarizar(img_gris, umbral)

##########################################

nivel = 5
img_posterizada = posterizar(img_gris, nivel)

plt.figure(figsize=(20, 10))

plt.subplot(131)
plt.title('Imagen inicial')
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))


plt.subplot(132)
plt.title('Solarizada')
plt.imshow(img_sol, cmap='gray')


plt.subplot(133)
plt.title('Posterizada')
plt.imshow(img_posterizada, cmap='gray')


plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize']=[10,5]
tamanio_img=100
R=np.ones((tamanio_img,tamanio_img))*255
G=np.ones((tamanio_img,tamanio_img))*50
B=np.ones((tamanio_img,tamanio_img))*50
imagen=np.dstack((R,G,B))
imagen=np.array(imagen, dtype=int)
plt.figure()
plt.imshow(imagen)
plt.title('paleta de colores')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread('nami.jpg', cv2.IMREAD_GRAYSCALE)
negativo = 255 - img
imagen = cv2.imread('nami.jpg')
img_gris = cv2.cvtColor(imagen, cv2.COLOR_BGR2GRAY)
negative = 255 - imagen

plt.figure(figsize=(20, 10))

plt.subplot(141)
plt.title('Imagen inicial')
plt.imshow(img, cmap='gray')
plt.axis('off')

plt.subplot(142)
plt.title('Negativo')
plt.imshow(negativo, cmap='gray')
plt.axis('off')

plt.subplot(143)
plt.title('Con color')
plt.imshow(cv2.cvtColor(imagen, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(144)
plt.title('Con color negative')
plt.imshow(negative, cmap='gray')
plt.axis('off')

plt.show()
